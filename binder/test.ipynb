# %% [markdown]
# # Does alcohol cause students' GPA to drop everywhere in the world?

# %% [markdown]
# Does alcohol cause students' GPA to drop?
#
# There has been multiple research on side effects of consuming alchol. One of the known research result is that drikning is directly related to decreased GPA of students. With the curiosity for the relationship of alcohol and GPA of students with different backgrounds and the relationship of alcohol consumption to other factors such as their background, I took a look at the statistic of Portugal students. The data were obtained in a survey of students math and portuguese language courses in secondary school in Portugal. It contains a lot of interesting social, gender and study information about students. You can use it for some EDA or try to predict students final grade.

# %%
import pandas as pd
import bqplot 
import numpy as np
import ipywidgets as widgets
import matplotlib.pyplot as plt

# %%
import pandas as pd
df = pd.read_csv('file:///Users/ivylee/Downloads/student-mat.csv')

# %%
df

# %%
def grapha(x, y):
    fig, ax = plt.subplots(figsize=(10,5))
    ax.bar(df[x], df[y])
    plt.show()
widgets.interact(grapha, x=['G3', 'Mjob','Fjob','age'],y=['Dalc', 'Walc']);

# %% [markdown]
# The graph above shows the relationship of
#
# absences - number of school absences
# Mjob - mother's job
# Fjob - father's job
# G3 - final grade (numeric: from 0 to 20, output target)
#
# with
# workday alcohol consumption (Dalc) and weekday alcohol consumption(Walc).
#
# It shows that studnts with highest scores had 0 to 1 drinks during workdays.. It also shows that students who drank the most got score from 5 - 15. The number of drinks significantly decreases for students who got over 15. However, this is not completely true as students who drank as little as 2 also got scores from 5 - 10.
#
# One thing I found interesting was that almost all students drank at level 5 for weekday consumptions, except the ones who got about 18 - 20 score.

# %% [markdown]
# Another interesting thing I found about this dataset was that students whose parents' job is in health field tend to drink less during workdays. I think this could be because their parents might be more cautious about what their child is consuming.

# %% [markdown]
# For the age, the interesting thing was that students of age 21 decreased in drinking significantly while the graph below shows American college students' grade drop at the age 21. Scholars says that this is because the legal age in United States is 21, and the grade starts to drop when they start drinking. For Portugies students, their drinking age is 18. At 21, we can see that their alcohol consumption decreased.

# %% [markdown]
# ![Screen%20Shot%202022-05-06%20at%209.32.37%20PM.png](attachment:Screen%20Shot%202022-05-06%20at%209.32.37%20PM.png)

# %% [markdown]
# Below is relationship between drinking frequency and GPA of Korean students. It also shows that students who drink often tends to have lower grades. Surprisingly, cigarette also affects GPA as well. It actually had more correlation with students' GPA than alcohol.

# %% [markdown]
# ![dataset-smokingdrinking.png](attachment:dataset-smokingdrinking.png)

# %% [markdown]
# For the graph above, each graph shows GPA for y and alcohol consumption for x for the left graph.  for the right graph, it shows GPA for y and cigerret consumption for x for the right graph.

# %%
# https://wol.iza.org/articles/does-substance-use-affect-educational-outcomes/long
# https://www.worklaw.co.kr/view/view.asp?in_cate=108&gopage=1&bi_pidx=30591
# https://www.kaggle.com/datasets/uciml/student-alcohol-consumption
